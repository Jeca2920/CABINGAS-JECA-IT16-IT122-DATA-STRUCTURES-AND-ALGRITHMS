# %%
print("Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters")
print("")
print("Algorithm – is any well-defined computational procedure that takes some value, or set of")
print("values as input and produces somevalue, as output. An Algorithm is thus a sequence of ")
print("computational steps that transform the input into the output.")
print("")
print("Data structures")
print("In computer science, a data structure is a data organization, management, andstorage format that ")
print("enable efficient access and modification. More precisely, a data structure is a collection of ")
print("data values, the relationships among them, and the functions or operations that can be applied")
print("to the data.")
print("")
print("Interface")
print("Represents  the set of operations that a data structure supports. An interface only provides the")
print("list of supported operations, type of parameters they can accept and return type of these operations.")
print("")
print("Implementation")
print("Also provides the definition of the algorithms used in the operations of the data structure. ")
print("Implementation provides the internal representation of a data structure. Implementation also provides")
print("the definition of the algorithms used in the operations of the data structure.")
print("")
print("Characteristics of a Data Structure")
print("")
print("Correctness − Data structure implementation should implement its interface correctly.")
print("")
print("Time Complexity − Running time or the execution time of operations of data structure")
print("                  must be as small as possible.")
print("")
print("Space Complexity − Memory usage of a data structure operation should be as little as possible.")
print("")
print("Data Search − Consider an inventory of 1 million (106) items of a store. If the application is to ")
print("              search an item, it has to search an item in 1 million (106) items every ")
print("              time slowing down the search. As data grows, search will become slower.")
print("")
print("Processor speed − Processor speed although being very high, falls limited if the")
print("                  data grows to billion records.")
print("")
print("Multiple requests − as thousands of users can search data simultaneously on a web server,")
print("                    even the fast server fails while searching the data.")
print("")
print("To solve the above-mentioned problems, data structures come to rescue. Data can be ")
print("organized in a data structure in such a way that all items may not be required to be ")
print("searched, and the required data can be searched almost instantly.")
print("")
print("Execution Time Cases")
print("")
print("There are three cases which are usually used to compare various data structure's")
print("execution time in a relative manner.")
print("")
print("Worst Case − This is the scenario where a particular data structure operation")
print("             takes maximum time it can take.If an operation's worst case time")
print("             is ƒ(n) then this operation will nottake more than ƒ(n) time where")
print("             ƒ(n) represents function of n.")
print("")
print("Average Case − this is the scenario depicting the average execution time of an")
print("             operation of a data structure. If an operation takes ƒ(n) time in execution,")
print("             then m operations will take mƒ(n) time.")
print("")
print("Best Case − this is the scenario depicting the least possible execution time of an ")
print("            operation of a data structure. If an operation takes ƒ(n) time in")
print("            execution, then the actual operation may take time as the random number")
print("            which would be maximum as ƒ(n).")
print("")
print("If you are aware of Object Oriented programming concepts, then a class also does")
print("the same thing, it collects different type of data under one single entity. ")
print("In simple language, Data Structures are structures programmed to store ordered data,")
print("so that various operations can be performed on it easily.. It represents  ")
print("the knowledge of data to be organized in memory.It should be designed and ")
print("implemented in such a way that it reduces the complexity and increases")
print("the efficiency.")
print("")
print("What is an Algorithm ?")
print("An algorithm is a finite set of instructions or logic, written in order,")
print("to accomplish a certain predefined task.")
print("")
print("Algorithm is not the complete code or program, it is just the core")
print("logic(solution) of a problem, which can be expressed either as an ")
print("informal high level description as pseudo code or using a flowchart.")
print("")
print("Every Algorithm must satisfy the following properties:")
print("")
print("Input- There should be 0 or more inputs supplied externally to the algorithm.")
print("")
print("Output- There should be atleast 1 output obtained.")
print("")
print("Definiteness- Every step of the algorithm should be clear and well defined.")
print("")
print("Finiteness- The algorithm should have finite number of steps.")
print("")
print("Correctness- Every step of the algorithm must generate a correct output.")
print("")
print("An algorithm is said to be efficient and fast, if it takes less time to ")
print("execute and consumes less memory space. The performance of an algorithm ")
print("is measured on the basis of following properties :")
print("")
print("Time Complexity")
print("Space Complexity")
print("Space Complexity")
print("")
print("It’s the amount of memory space required by the algorithm, during the course")
print("of its execution.Space complexity must be taken seriously for multi-user systems")
print("and in situations where limited memory is available.")
print("")
print("An algorithm generally requires space for following components :")
print("")
print("Instruction Space: Its the space required to store the executable version of the program")
print("")
print("Data Space: It’s the space required to store all the constants and variables(including")
print(" temporary variables) value.")
print("")
print("Environment Space: It’s the space required to store the environment information needed ")
print("to resume the suspended function.")
print("")
print("Time Complexity")
print("")
print(" It's generally a good practice to try to keep the time required minimum,so that our ")
print("algorithm completes its execution in the minimum time possible.")
print(". We will study about Time Complexity in details in later sections.")
print("")
# Out:
# Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters
#
# Algorithm – is any well-defined computational procedure that takes some value, or set of
# values as input and produces somevalue, as output. An Algorithm is thus a sequence of
# computational steps that transform the input into the output.
#
# Data structures
# In computer science, a data structure is a data organization, management, andstorage format that
# enable efficient access and modification. More precisely, a data structure is a collection of
# data values, the relationships among them, and the functions or operations that can be applied
# to the data.
#
# Interface
# Represents  the set of operations that a data structure supports. An interface only provides the
# list of supported operations, type of parameters they can accept and return type of these operations.
#
# Implementation
# Also provides the definition of the algorithms used in the operations of the data structure.
# ...

# %%
print("Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters")
print("")
print("Chapter 2 ")
print("In this chapter, l have learn how to define and use references and complex data structures.")
print("After you learn the fundamentals, you'll apply the new techniques to implement a biologically")
print("important algorithm. These techniques are also fundamental to the implementation ofobject-oriented ")
print("programming, as you'll see in chapter 3")
print("")
# Out:
# Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters
#
# Chapter 2
# In this chapter, l have learn how to define and use references and complex data structures.
# After you learn the fundamentals, you'll apply the new techniques to implement a biologically
# important algorithm. These techniques are also fundamental to the implementation ofobject-oriented
# programming, as you'll see in chapter 3

# %%
print("Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters")
print("")
print("Chapter 3. The algorithm we'll study is called approximate string matching. ")
print("")
# Out:
# Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters
#
# Chapter 3. The algorithm we'll study is called approximate string matching.
